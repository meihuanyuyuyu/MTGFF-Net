# %%
import torch
from skimage.color import rgb2hed
import matplotlib.pyplot as plt

img = torch.load('/root/autodl-tmp/data/cpm17/test/imgs.pt')[12:13]
img2=rgb2hed(img[0].permute(1, 2, 0).numpy())
print(img2.shape,img2.max())
plt.imshow(img2[...,0])
plt.show()
# Out:
# (256, 256, 3) 0.2594911827713588
