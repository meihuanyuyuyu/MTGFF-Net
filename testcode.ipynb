# %%
from Netlib.MTGFFlib.tools.dataset import MtgffPannukeDataset

data = MtgffPannukeDataset('data/pannuke')
img, label, boxes, masks, cls, semantic = data[0]
print(img.shape, label.shape, boxes.shape, masks.shape, cls.shape, semantic.shape)
# Out:
# Loading data into memory
# torch.Size([3, 256, 256]) torch.Size([2, 256, 256]) torch.Size([8, 4]) torch.Size([8, 28, 28]) torch.Size([8]) torch.Size([256, 256])

# %%
import matplotlib.pyplot as plt

plt.imshow(img.permute(1, 2, 0))
plt.show()

plt.imshow(label[0])
plt.show()

plt.imshow(semantic)
plt.show()

plt.imshow(masks[0])
plt.show()
